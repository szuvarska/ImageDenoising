# %%
from denoise import denoise

# %%
denoise("img/mini_logo.png", noise_strength=0.9, extfield_strength=0.9, burnin=50000, loops=500000)

# %%
denoise("img/mini_logo.png", noise_strength=0.9, extfield_strength=0.99, burnin=50000, loops=500000)

# %%
denoise("img/mini_logo.png", noise_strength=0.9, extfield_strength=0.5, burnin=50000, loops=500000)

# %%
denoise("img/mini_text.png", noise_strength=0.9, extfield_strength=0.9, burnin=50000, loops=500000)

# %%
denoise("img/mini_text.png", noise_strength=0.9, extfield_strength=0.99, burnin=50000, loops=500000)

# %%
denoise("img/mini_text.png", noise_strength=0.9, extfield_strength=0.5, burnin=50000, loops=500000)
