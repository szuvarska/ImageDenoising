# %%
from denoise import denoise

# %%
denoise(
    "img/mini_logo.png",
    noise_strength=0.8,
    extfield_strength=0.9,
    burnin=50000,
    loops=500000,
    fig_title="Default neighbours function",
)

# %%
denoise(
    "img/mini_logo.png",
    noise_strength=0.8,
    extfield_strength=0.9,
    burnin=50000,
    loops=500000,
    use_default_neighbours=False,
    fig_title="Improved neighbours function",
)
